# %%
import csv
import os
import math
import pandas as pd
import numpy as np

station_data = pd.read_csv('station-coordinates.csv')

station_data.head()
# Out:
#          Location  Latitude  Longtitude
# 0   Upper Thomson  1.372966  103.828508
# 1        Clementi  1.316181  103.764938
# 2        Buangkok  1.380076  103.894116
# 3  Sentosa Island  1.249404  103.830321
# 4       Chai Chee  1.324524  103.923053

# %%
data_2019 = pd.read_csv('2019.csv', encoding='iso-8859-1')

data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8258 entries, 0 to 8257
# Data columns (total 15 columns):
# Location                         8258 non-null object
# No. of Cases                     8258 non-null object
# Date                             8258 non-null object
# Latitude                         8258 non-null float64
# Longtitude                       8258 non-null float64
# Closest Location                 8258 non-null object
# Daily Rainfall Total (mm)        8258 non-null object
# Highest 30 Min Rainfall (mm)     8258 non-null object
# Highest 60 Min Rainfall (mm)     8258 non-null object
# Highest 120 Min Rainfall (mm)    8258 non-null object
# Mean Temperature (°C)            8258 non-null object
# Maximum Temperature (°C)         8258 non-null object
# Minimum Temperature (°C)         8258 non-null object
# Mean Wind Speed (km/h)           8258 non-null object
# Max Wind Speed (km/h)            8258 non-null object
# dtypes: float64(2), object(13)
# ...

# %%
df = data_2019.copy()

df = df.drop(df.columns[6:], axis=1)

df.drop(columns=["Location", "Latitude", "Longtitude"], inplace=True)

df.head()
# Out:
#   No. of Cases        Date Closest Location
# 0            1  04/01/2019        Chai Chee
# 1            1  04/01/2019        Chai Chee
# 2            3  04/01/2019        Chai Chee
# 3            2  04/01/2019        Chai Chee
# 4            3  04/01/2019        Chai Chee

# %%
'''
lat = np.reshape(df['Latitude'].to_numpy(), (-1, 1))
long = np.reshape(df['Longtitude'].to_numpy(), (-1, 1))

coords = np.hstack((lat, long))

for c in np.unique(coords, axis=1):
    print(c)
'''

count = 0

data = []

for station in station_data.iloc[:,0]:
    for loc in df.iloc[:,0]:
        if station in loc:
            count += 1
            data.append(loc)

# %%
for loc in df.iloc[:,2]: print(loc)
# Out:
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Simei
# Simei
# Simei
# Simei
# Simei
# Simei
# Simei
# Simei
# Simei
# Jurong (North)
# Jurong (North)
# Jurong (North)
# Jurong (North)
# Jurong (North)
# Jurong (North)
# Chai Chee
# Chai Chee
# Chai Chee
# Buangkok
# Buangkok
# Buangkok
# Buangkok
# Bukit Panjang
# Bukit Panjang
# Bukit Panjang
# Bukit Panjang
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Chai Chee
# Simei
# Chai Chee
# Simei
# Simei
# Simei
# Pasir Panjang
# Queenstown
# Pasir Ris (Central)
# Pasir Ris (Central)
# Pasir Ris (Central)
# Yishun
# Yishun
# Yishun
# Ang Mo Kio
# Ang Mo Kio
# ...

# %%
# Don't run this

for loc in data:
    if loc in np.unique(data)[:1]:
        data.remove(loc)

for loc in np.unique(data): print(loc)
# Out:
# Admiralty Road West
# Ang Mo Kio Avenue 1 (Blk 218)
# Ang Mo Kio Avenue 1 (Blk 220)
# Ang Mo Kio Avenue 1 (Blk 304)
# Ang Mo Kio Avenue 1 (Blk 308A)
# Ang Mo Kio Avenue 1 (Blk 310C)
# Ang Mo Kio Avenue 1 (Blk 337)
# Ang Mo Kio Avenue 1(Blk 304)
# Ang Mo Kio Avenue 10 (Blk 411)
# Ang Mo Kio Avenue 10 (Blk 412)
# Ang Mo Kio Avenue 10 (Blk 413)
# Ang Mo Kio Avenue 10 (Blk 414)
# Ang Mo Kio Avenue 10 (Blk 415)
# Ang Mo Kio Avenue 10 (Blk 416)
# Ang Mo Kio Avenue 10 (Blk 417)
# Ang Mo Kio Avenue 10 (Blk 418)
# Ang Mo Kio Avenue 10 (Blk 419)
# Ang Mo Kio Avenue 10 (Blk 420)
# Ang Mo Kio Avenue 10 (Blk 421)
# Ang Mo Kio Avenue 10 (Blk 432)
# Ang Mo Kio Avenue 10 (Blk 435)
# Ang Mo Kio Avenue 10 (Blk 436)
# Ang Mo Kio Avenue 10 (Blk 437)
# Ang Mo Kio Avenue 10 (Blk 438)
# Ang Mo Kio Avenue 10 (Blk 440)
# Ang Mo Kio Avenue 10 (Blk 441)
# Ang Mo Kio Avenue 10 (Blk 443)
# Ang Mo Kio Avenue 10 (Blk 444)
# Ang Mo Kio Avenue 10 (Blk 445)
# Ang Mo Kio Avenue 10 (Blk 447)
# ...

# %%
df = df[df.Location.isin(np.unique(data))]
df = df.reset_index(drop=True)
df = df.drop(columns="Location")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-625f6757319f> in <module>
# ----> 1 df = df[df.Location.isin(np.unique(data))]
#       2 df = df.reset_index(drop=True)
#       3 df = df.drop(columns="Location")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Location'

# %%
df.to_csv('2019_ds.csv', index=False)
